# %% [markdown]
# <a href="https://colab.research.google.com/github/dhruvsbe/neptune/blob/master/neptuneMachineLearning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Neptune Water Classifier: Machine Learning System

# %% [markdown]
# Our Goal: To provide an effective system for predicting whether water sources are drinkable or non-drinkable for disadvantaged communities in third-world countries

# %%
# importing packages
from sklearn.ensemble import RandomForestClassifier
import pandas as pd
from sklearn import metrics
import numpy as np
from sklearn.metrics import accuracy_score 
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import pickle

# %%
# setting data as a dataframe for machine learning use
waterData = pd.read_csv("/content/waterQuality1.csv")

# %% [markdown]
# data before dropping empty values and correcting types:

# %%
waterData.head(n = 5).style.background_gradient(cmap = "Blues_r")
# Out:
# <style type="text/css">
# #T_b0026_row0_col0 {
#   background-color: #74b3d8;
#   color: #000000;
# }
# #T_b0026_row0_col2, #T_b0026_row0_col6, #T_b0026_row0_col12, #T_b0026_row0_col14, #T_b0026_row0_col17, #T_b0026_row1_col0, #T_b0026_row1_col3, #T_b0026_row1_col13, #T_b0026_row1_col17, #T_b0026_row1_col19, #T_b0026_row2_col2, #T_b0026_row2_col4, #T_b0026_row2_col15, #T_b0026_row2_col16, #T_b0026_row3_col2, #T_b0026_row3_col5, #T_b0026_row3_col7, #T_b0026_row3_col8, #T_b0026_row3_col9, #T_b0026_row3_col10, #T_b0026_row3_col18, #T_b0026_row3_col19, #T_b0026_row4_col11 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_b0026_row0_col3 {
#   background-color: #dae8f6;
#   color: #000000;
# }
# #T_b0026_row0_col4 {
#   background-color: #dbe9f6;
#   color: #000000;
# }
# ...

# %%
waterData.tail(n = 5).style.background_gradient(cmap = "Blues_r")
# Out:
# <style type="text/css">
# #T_cdc2b_row0_col0, #T_cdc2b_row1_col0, #T_cdc2b_row3_col2, #T_cdc2b_row4_col2 {
#   background-color: #6caed6;
#   color: #f1f1f1;
# }
# #T_cdc2b_row0_col2, #T_cdc2b_row0_col9, #T_cdc2b_row0_col10, #T_cdc2b_row1_col3, #T_cdc2b_row1_col7, #T_cdc2b_row1_col9, #T_cdc2b_row1_col10, #T_cdc2b_row2_col2, #T_cdc2b_row2_col5, #T_cdc2b_row2_col7, #T_cdc2b_row2_col9, #T_cdc2b_row2_col10, #T_cdc2b_row2_col14, #T_cdc2b_row2_col17, #T_cdc2b_row3_col0, #T_cdc2b_row3_col4, #T_cdc2b_row3_col6, #T_cdc2b_row3_col8, #T_cdc2b_row3_col9, #T_cdc2b_row3_col10, #T_cdc2b_row3_col11, #T_cdc2b_row3_col12, #T_cdc2b_row3_col13, #T_cdc2b_row3_col14, #T_cdc2b_row3_col15, #T_cdc2b_row3_col16, #T_cdc2b_row3_col17, #T_cdc2b_row3_col18, #T_cdc2b_row3_col19, #T_cdc2b_row4_col5, #T_cdc2b_row4_col9, #T_cdc2b_row4_col10, #T_cdc2b_row4_col14, #T_cdc2b_row4_col17 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_cdc2b_row0_col3 {
#   background-color: #f0f6fd;
#   color: #000000;
# }
# ...

# %%
waterData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7999 entries, 0 to 7998
# Data columns (total 21 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   aluminium    7999 non-null   float64
#  1   ammonia      7999 non-null   object
#  2   arsenic      7999 non-null   float64
#  3   barium       7999 non-null   float64
#  4   cadmium      7999 non-null   float64
#  5   chloramine   7999 non-null   float64
#  6   chromium     7999 non-null   float64
#  7   copper       7999 non-null   float64
#  8   flouride     7999 non-null   float64
#  9   bacteria     7999 non-null   float64
#  10  viruses      7999 non-null   float64
#  11  lead         7999 non-null   float64
#  12  nitrates     7999 non-null   float64
#  13  nitrites     7999 non-null   float64
#  14  mercury      7999 non-null   float64
#  15  perchlorate  7999 non-null   float64
#  16  radium       7999 non-null   float64
#  17  selenium     7999 non-null   float64
# ...

# %%
#replacing empty values with null and correcting types
waterData['ammonia'] = waterData['ammonia'].replace('#NUM!',np.nan)
waterData['ammonia'] = waterData['ammonia'].astype('float')
waterData['is_safe'] = waterData['is_safe'].replace('#NUM!',np.nan)
waterData['is_safe'] = waterData['is_safe'].astype('float')

# %%
#dropping null values
waterData.dropna(inplace=True)

# %% [markdown]
# data after dropping empty values and correcting types:

# %%
waterData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7996 entries, 0 to 7998
# Data columns (total 21 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   aluminium    7996 non-null   float64
#  1   ammonia      7996 non-null   float64
#  2   arsenic      7996 non-null   float64
#  3   barium       7996 non-null   float64
#  4   cadmium      7996 non-null   float64
#  5   chloramine   7996 non-null   float64
#  6   chromium     7996 non-null   float64
#  7   copper       7996 non-null   float64
#  8   flouride     7996 non-null   float64
#  9   bacteria     7996 non-null   float64
#  10  viruses      7996 non-null   float64
#  11  lead         7996 non-null   float64
#  12  nitrates     7996 non-null   float64
#  13  nitrites     7996 non-null   float64
#  14  mercury      7996 non-null   float64
#  15  perchlorate  7996 non-null   float64
#  16  radium       7996 non-null   float64
#  17  selenium     7996 non-null   float64
# ...

# %%
waterData.head(n = 10).style.background_gradient(cmap = "Blues_r")
# Out:
# <style type="text/css">
# #T_3c562_row0_col0, #T_3c562_row6_col16, #T_3c562_row8_col9 {
#   background-color: #4594c7;
#   color: #f1f1f1;
# }
# #T_3c562_row0_col1 {
#   background-color: #135fa7;
#   color: #f1f1f1;
# }
# #T_3c562_row0_col2, #T_3c562_row0_col6, #T_3c562_row0_col20, #T_3c562_row1_col3, #T_3c562_row1_col13, #T_3c562_row1_col20, #T_3c562_row2_col2, #T_3c562_row2_col4, #T_3c562_row3_col2, #T_3c562_row3_col5, #T_3c562_row3_col18, #T_3c562_row3_col20, #T_3c562_row4_col20, #T_3c562_row5_col20, #T_3c562_row6_col7, #T_3c562_row6_col12, #T_3c562_row6_col17, #T_3c562_row6_col19, #T_3c562_row7_col0, #T_3c562_row7_col2, #T_3c562_row7_col11, #T_3c562_row7_col15, #T_3c562_row7_col16, #T_3c562_row8_col1, #T_3c562_row8_col19, #T_3c562_row8_col20, #T_3c562_row9_col8, #T_3c562_row9_col9, #T_3c562_row9_col10, #T_3c562_row9_col14, #T_3c562_row9_col20 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# ...

# %%
waterData.tail(n = 10).style.background_gradient(cmap = "Blues_r")
# Out:
# <style type="text/css">
# #T_cae1e_row0_col0, #T_cae1e_row6_col4, #T_cae1e_row8_col0 {
#   background-color: #084d96;
#   color: #f1f1f1;
# }
# #T_cae1e_row0_col1, #T_cae1e_row0_col4, #T_cae1e_row0_col13, #T_cae1e_row0_col14, #T_cae1e_row0_col15, #T_cae1e_row0_col16, #T_cae1e_row0_col19, #T_cae1e_row1_col2, #T_cae1e_row1_col13, #T_cae1e_row2_col13, #T_cae1e_row2_col20, #T_cae1e_row3_col13, #T_cae1e_row3_col20, #T_cae1e_row4_col12, #T_cae1e_row4_col13, #T_cae1e_row4_col20, #T_cae1e_row5_col11, #T_cae1e_row5_col13, #T_cae1e_row5_col17, #T_cae1e_row5_col20, #T_cae1e_row6_col8, #T_cae1e_row6_col13, #T_cae1e_row6_col17, #T_cae1e_row6_col18, #T_cae1e_row6_col20, #T_cae1e_row7_col0, #T_cae1e_row7_col6, #T_cae1e_row7_col13, #T_cae1e_row7_col20, #T_cae1e_row8_col3, #T_cae1e_row8_col5, #T_cae1e_row8_col7, #T_cae1e_row8_col20, #T_cae1e_row9_col13, #T_cae1e_row9_col20 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_cae1e_row0_col2, #T_cae1e_row3_col2, #T_cae1e_row6_col1 {
# ...

# %% [markdown]
# feature importance:

# %%
x = waterData.iloc[:,0:20]  # all of the features of the dataset
y = waterData.iloc[:,-1]    # label of the dataset
rf = RandomForestClassifier()
rf.fit(x,y)
print(rf.feature_importances_) # printing the importance of the features

# plot graph of the top 10 most important features
feat_importances = pd.Series(rf.feature_importances_, index=x.columns)
feat_importances.nlargest(10).plot(kind='barh')
plt.title('RandomForest')
plt.xlabel('Feature Importance Score')
plt.ylabel('Feature')
plt.show()
# Out:
# [0.21165291 0.04526232 0.0551081  0.0297836  0.11377779 0.04834252
#  0.03357906 0.02314068 0.01983748 0.02832662 0.03424504 0.02423896
#  0.0371798  0.0315173  0.01450985 0.11034456 0.03594278 0.01795737
#  0.0494163  0.03583696]

# %%
# setting features and labels
features = ['uranium','radium','nitrates','chloramine','ammonia','silver','arsenic','perchlorate','cadmium','aluminium'] #only using the top 10 most important features
label = 'is_safe'

# %% [markdown]
# machine learning model:

# %%
# splitting data into training and testing sets
train, test = train_test_split(waterData, test_size = 0.25, random_state = 1)
trainX = train[features]
trainY = train[label]
testX = test[features]
testY = test[label]

# %%
# training the random forest classifier model and printing accuracy
rf.fit(trainX, trainY)
y_pred = rf.predict(testX)
print("Accuracy: ", metrics.accuracy_score(testY, y_pred))
# Out:
# Accuracy:  0.9654827413706853

# %%
# pickling the model for use with website
pickle.dump(rf, open("water.pkl", "wb"))

# %% [markdown]
# input function:

# %%
# input function for website
predict = {}

print("Please type the numbers as prompted")
for feature in features:
  val = input(feature + ":")
  predict[feature] = val 

predict = pd.DataFrame(predict, index=[0])

output = rf.predict(predict)

print()
print("Model Prediction of \'is_safe\' — ", end = "")
print(output)
print()

if output == [1]:
  print("Based on the model, this data indicates the water is safe.")
if output == [0]:
  print("Based on the model, this data indicates the water is NOT safe.")
# Out:
# Please type the numbers as prompted
# uranium:0.02
# radium:6.78
# nitrates:16.08
# chloramine:0.35
# ammonia:9.08
# silver:0.34
# arsenic:0.04
# perchlorate:37.75
# cadmium:0.007
# aluminium:1.65
#
# Model Prediction of 'is_safe' — [1.]
#
# Based on the model, this data indicates the water is safe.
